# %% [markdown]
# # Step 1: Imports and Reading Data
#
# Data Source: https://data.lacity.org/Public-Safety/Arrest-Data-from-2020-to-Present/amvf-fr72/about_data

# %%
import pandas as pd # Manipulate Data Frame
import numpy as np # Computation
import matplotlib.pyplot as plt #visualization
import seaborn as sns #visualization
plt.style.use('ggplot')

# %%
# Load the dataset from a CSV File
pd.read_csv('C:\\Users\\eledd\\OneDrive\\Desktop\\Arrest_2020.csv')
# Out:
#         Report ID Report Type     Arrest Date    Time  Area ID   Area Name  \
# 0       231413977         RFC  7/13/2023 0:00  2330.0       14     Pacific
# 1       231715213         RFC   9/1/2023 0:00  2300.0       17  Devonshire
# 2       230612568         RFC  7/14/2023 0:00  2150.0        6   Hollywood
# 3       230119897         RFC  9/13/2023 0:00  1332.0        1     Central
# 4       230214008         RFC   7/4/2023 0:00  1445.0        2     Rampart
# ...           ...         ...             ...     ...      ...         ...
# 254428    6547005     BOOKING   2/4/2023 0:00  1300.0        1     Central
# 254429    6635363     BOOKING   7/4/2023 0:00  1130.0       18   Southeast
# 254430    6636889     BOOKING   7/6/2023 0:00  2050.0        4  Hollenbeck
# 254431    6635947     BOOKING   7/5/2023 0:00   835.0       14     Pacific
# 254432    6634656     BOOKING   7/3/2023 0:00   120.0        7    Wilshire
#
#         Reporting District  Age Sex Code Descent Code  ...  \
# 0                     1412   29        M            H  ...
# 1                     1738   17        F            H  ...
# 2                      677   30        M            O  ...
# 3                      148   50        M            A  ...
# 4                      266   38        M            H  ...
# ...                    ...  ...      ...          ...  ...
# 254428                 154   38        F            W  ...
# 254429                1844   33        M            H  ...
# 254430                 467   58        M            H  ...
# 254431                1494   66        M            O  ...
# 254432                 789   36        M            H  ...
#
#               Disposition Description  \
# 0         MISDEMEANOR COMPLAINT FILED
# 1                  COUNSELED/RELEASED
# 2         MISDEMEANOR COMPLAINT FILED
# 3         MISDEMEANOR COMPLAINT FILED
# 4         MISDEMEANOR COMPLAINT FILED
# ...                               ...
# 254428    MISDEMEANOR COMPLAINT FILED
# 254429  849(B)(1) PC/TECHNICAL ARREST
# 254430    MISDEMEANOR COMPLAINT FILED
# 254431    MISDEMEANOR COMPLAINT FILED
# 254432    MISDEMEANOR COMPLAINT FILED
#
#                                          Address  \
# 0                BROOKS                       AV
# 1       15800    TULSA                        ST
# 2                                        WESTERN
# 3                                            5TH
# 4                                    BONNIE BRAE
# ...                                          ...
# 254428    100 W  5TH                          ST
# 254429    600 E  110TH                        ST
# 254430   2700 E  1ST                          ST
# 254431    300    WORLD WAY                    WY
# 254432           21ST                         ST
#
#                            Cross Street      LAT       LON  \
# 0       OCEAN FRONT                  WK  33.9908 -118.4765
# 1                                   NaN  34.2682 -118.4760
# 2                              MARATHON  34.0845 -118.3091
# 3                                GLADYS  34.0421 -118.2405
# 4                                   8TH  34.0539 -118.2756
# ...                                 ...      ...       ...
# 254428                              NaN  34.0467 -118.2485
# 254429                              NaN  33.9356 -118.2652
# 254430                              NaN  34.0421 -118.2060
# 254431                              NaN  33.9420 -118.4095
# 254432  3RD                          ST  34.0380 -118.3201
#
#                          Location   Booking Date Booking Time  \
# 0       POINT (-118.4765 33.9908)            NaN          NaN
# 1        POINT (-118.476 34.2682)            NaN          NaN
# 2       POINT (-118.3091 34.0845)            NaN          NaN
# 3       POINT (-118.2405 34.0421)            NaN          NaN
# 4       POINT (-118.2756 34.0539)            NaN          NaN
# ...                           ...            ...          ...
# 254428  POINT (-118.2485 34.0467)  2/4/2023 0:00       1838.0
# 254429  POINT (-118.2652 33.9356)  7/4/2023 0:00       1320.0
# 254430   POINT (-118.206 34.0421)  7/6/2023 0:00       2247.0
# 254431   POINT (-118.4095 33.942)  7/5/2023 0:00       1108.0
# 254432   POINT (-118.3201 34.038)  7/3/2023 0:00        330.0
#
#              Booking Location  Booking Location Code
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
# ...                       ...                    ...
# 254428  METRO - JAIL DIVISION                 4273.0
# 254429                77TH ST                 4212.0
# 254430  METRO - JAIL DIVISION                 4273.0
# 254431                PACIFIC                 4214.0
# 254432  METRO - JAIL DIVISION                 4273.0
#
# [254433 rows x 25 columns]

# %%
# DF become my variable to reference, instead of using 
df = pd.read_csv('C:\\Users\\eledd\\OneDrive\\Desktop\\Arrest_2020.csv')

# %%
#Display the first 5 rows of the dataset. # can be change to show more rows.
df.head()
# Out:
#    Report ID Report Type     Arrest Date    Time  Area ID   Area Name  \
# 0  231413977         RFC  7/13/2023 0:00  2330.0       14     Pacific
# 1  231715213         RFC   9/1/2023 0:00  2300.0       17  Devonshire
# 2  230612568         RFC  7/14/2023 0:00  2150.0        6   Hollywood
# 3  230119897         RFC  9/13/2023 0:00  1332.0        1     Central
# 4  230214008         RFC   7/4/2023 0:00  1445.0        2     Rampart
#
#    Reporting District  Age Sex Code Descent Code  ...  \
# 0                1412   29        M            H  ...
# 1                1738   17        F            H  ...
# 2                 677   30        M            O  ...
# 3                 148   50        M            A  ...
# 4                 266   38        M            H  ...
#
#        Disposition Description                                   Address  \
# 0  MISDEMEANOR COMPLAINT FILED           BROOKS                       AV
# 1           COUNSELED/RELEASED  15800    TULSA                        ST
# 2  MISDEMEANOR COMPLAINT FILED                                   WESTERN
# 3  MISDEMEANOR COMPLAINT FILED                                       5TH
# 4  MISDEMEANOR COMPLAINT FILED                               BONNIE BRAE
#
#                       Cross Street      LAT       LON  \
# 0  OCEAN FRONT                  WK  33.9908 -118.4765
# 1                              NaN  34.2682 -118.4760
# 2                         MARATHON  34.0845 -118.3091
# 3                           GLADYS  34.0421 -118.2405
# 4                              8TH  34.0539 -118.2756
#
#                     Location Booking Date Booking Time  Booking Location  \
# 0  POINT (-118.4765 33.9908)          NaN          NaN               NaN
# 1   POINT (-118.476 34.2682)          NaN          NaN               NaN
# 2  POINT (-118.3091 34.0845)          NaN          NaN               NaN
# 3  POINT (-118.2405 34.0421)          NaN          NaN               NaN
# 4  POINT (-118.2756 34.0539)          NaN          NaN               NaN
#
#    Booking Location Code
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 25 columns]

# %%
#Display the Last 5 rows of the dataset. # can be change to show more rows.
df.tail()
# Out:
#         Report ID Report Type    Arrest Date    Time  Area ID   Area Name  \
# 254428    6547005     BOOKING  2/4/2023 0:00  1300.0        1     Central
# 254429    6635363     BOOKING  7/4/2023 0:00  1130.0       18   Southeast
# 254430    6636889     BOOKING  7/6/2023 0:00  2050.0        4  Hollenbeck
# 254431    6635947     BOOKING  7/5/2023 0:00   835.0       14     Pacific
# 254432    6634656     BOOKING  7/3/2023 0:00   120.0        7    Wilshire
#
#         Reporting District  Age Sex Code Descent Code  ...  \
# 254428                 154   38        F            W  ...
# 254429                1844   33        M            H  ...
# 254430                 467   58        M            H  ...
# 254431                1494   66        M            O  ...
# 254432                 789   36        M            H  ...
#
#               Disposition Description  \
# 254428    MISDEMEANOR COMPLAINT FILED
# 254429  849(B)(1) PC/TECHNICAL ARREST
# 254430    MISDEMEANOR COMPLAINT FILED
# 254431    MISDEMEANOR COMPLAINT FILED
# 254432    MISDEMEANOR COMPLAINT FILED
#
#                                         Address  \
# 254428   100 W  5TH                          ST
# 254429   600 E  110TH                        ST
# 254430  2700 E  1ST                          ST
# 254431   300    WORLD WAY                    WY
# 254432          21ST                         ST
#
#                            Cross Street      LAT       LON  \
# 254428                              NaN  34.0467 -118.2485
# 254429                              NaN  33.9356 -118.2652
# 254430                              NaN  34.0421 -118.2060
# 254431                              NaN  33.9420 -118.4095
# 254432  3RD                          ST  34.0380 -118.3201
#
#                          Location   Booking Date Booking Time  \
# 254428  POINT (-118.2485 34.0467)  2/4/2023 0:00       1838.0
# 254429  POINT (-118.2652 33.9356)  7/4/2023 0:00       1320.0
# 254430   POINT (-118.206 34.0421)  7/6/2023 0:00       2247.0
# 254431   POINT (-118.4095 33.942)  7/5/2023 0:00       1108.0
# 254432   POINT (-118.3201 34.038)  7/3/2023 0:00        330.0
#
#              Booking Location  Booking Location Code
# 254428  METRO - JAIL DIVISION                 4273.0
# 254429                77TH ST                 4212.0
# 254430  METRO - JAIL DIVISION                 4273.0
# 254431                PACIFIC                 4214.0
# 254432  METRO - JAIL DIVISION                 4273.0
#
# [5 rows x 25 columns]

# %%
# allows users to know how many "rows,columns" are in the CSV.
df.shape
# Out:
# (254433, 25)

# %%
#looks for any duplicate data in the dataset.
df.duplicated().sum()
# Out:
# 0

# %%
#removes all duplcate data. If there was any. 
df.drop_duplicates(inplace=True)

# %%
# shows all column in the dataset.
df.columns
# Out:
# Index(['Report ID', 'Report Type', 'Arrest Date', 'Time', 'Area ID',
#        'Area Name', 'Reporting District', 'Age', 'Sex Code', 'Descent Code',
#        'Charge Group Code', 'Charge Group Description', 'Arrest Type Code',
#        'Charge', 'Charge Description', 'Disposition Description', 'Address',
#        'Cross Street', 'LAT', 'LON', 'Location', 'Booking Date',
#        'Booking Time', 'Booking Location', 'Booking Location Code'],
#       dtype='object')

# %%
#allows us to use a subset of our columns we only want to use.
df = df [['Report ID', 'Report Type', 'Arrest Date', 'Time',
       'Area Name', 'Age', 'Sex Code', 'Descent Code',
       'Charge Group Description', 'Arrest Type Code',
       'Charge', 'Charge Description', 'Disposition Description', 'LAT', 
        'LON', 'Booking Date','Booking Time', 'Booking Location',]].copy()

# %%
# now you see 25 columns become 19 from the removal of unwanted data.
df.shape
# Out:
# (254433, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254433 entries, 0 to 254432
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Report ID                 254433 non-null  int64
#  1   Report Type               254433 non-null  object
#  2   Arrest Date               254433 non-null  object
#  3   Time                      254419 non-null  float64
#  4   Area Name                 254433 non-null  object
#  5   Age                       254433 non-null  int64
#  6   Sex Code                  254433 non-null  object
#  7   Descent Code              254433 non-null  object
#  8   Charge Group Description  233192 non-null  object
#  9   Arrest Type Code          254432 non-null  object
#  10  Charge                    254433 non-null  object
#  11  Charge Description        233233 non-null  object
#  12  Disposition Description   234963 non-null  object
#  13  LAT                       254433 non-null  float64
#  14  LON                       254433 non-null  float64
#  15  Booking Date              200677 non-null  object
#  16  Booking Time              200677 non-null  float64
#  17  Booking Location          200644 non-null  object
# dtypes: float64(4), int64(2), object(12)
# memory usage: 34.9+ MB

# %% [markdown]
# # STEP 2: DATA CLEANING

# %%
#Arrest Date & Booking Date COLUMN need to be changeed to DATETIME
df.dtypes
# Out:
# Report ID                     int64
# Report Type                  object
# Arrest Date                  object
# Time                        float64
# Area Name                    object
# Age                           int64
# Sex Code                     object
# Descent Code                 object
# Charge Group Description     object
# Arrest Type Code             object
# Charge                       object
# Charge Description           object
# Disposition Description      object
# LAT                         float64
# LON                         float64
# Booking Date                 object
# Booking Time                float64
# Booking Location             object
# dtype: object

# %%
#Change Arrest Date to date type
df['Arrest Date'] = pd.to_datetime(df['Arrest Date']).copy()

# %%
#Change Booking Date to date type
df['Booking Date'] = pd.to_datetime(df['Booking Date']).copy()

# %%
#format TIME to 12-hour format
df['Booking Time'] = pd.to_datetime(df['Booking Time'], format='%H%M', errors='coerce').dt.strftime('%I:%M %p').copy()

# %%
#format TIME to 12-hour format
df['Time'] = pd.to_datetime(df['Time'], format='%H%M', errors='coerce').dt.strftime('%I:%M %p').copy()

# %%
df
# Out:
#         Report ID Report Type Arrest Date      Time   Area Name  Age Sex Code  \
# 0       231413977         RFC  2023-07-13  11:30 PM     Pacific   29        M
# 1       231715213         RFC  2023-09-01  11:00 PM  Devonshire   17        F
# 2       230612568         RFC  2023-07-14  09:50 PM   Hollywood   30        M
# 3       230119897         RFC  2023-09-13  01:32 PM     Central   50        M
# 4       230214008         RFC  2023-07-04  02:45 PM     Rampart   38        M
# ...           ...         ...         ...       ...         ...  ...      ...
# 254428    6547005     BOOKING  2023-02-04  01:00 PM     Central   38        F
# 254429    6635363     BOOKING  2023-07-04  11:30 AM   Southeast   33        M
# 254430    6636889     BOOKING  2023-07-06  08:50 PM  Hollenbeck   58        M
# 254431    6635947     BOOKING  2023-07-05  08:35 AM     Pacific   66        M
# 254432    6634656     BOOKING  2023-07-03  12:00 PM    Wilshire   36        M
#
#        Descent Code        Charge Group Description Arrest Type Code  \
# 0                 H                             NaN                I
# 1                 H                             NaN                M
# 2                 O             Prostitution/Allied                M
# 3                 A                             NaN                M
# 4                 H                             NaN                I
# ...             ...                             ...              ...
# 254428            W  Miscellaneous Other Violations                F
# 254429            H                   Vehicle Theft                F
# 254430            H                      Drunkeness                M
# 254431            O       Moving Traffic Violations                M
# 254432            H         Driving Under Influence                M
#
#              Charge                         Charge Description  \
# 0          25620(A)                                        NaN
# 1       45.03(A)LAM                                        NaN
# 2          647(B)PC                               PROSTITUTION
# 3       41.18A1LAMC                                        NaN
# 4       41.27(C)LAM                                        NaN
# ...             ...                                        ...
# 254428  594(B)(1)PC       VANDALISM W/LOSS VALUED EQ OR > $400
# 254429  487(D)(1)PC                 GRAND THEFT AUTO/HORSE/ETC
# 254430     647(F)PC            DISORD CONDUCT:UI/DRUG, ALCOHOL
# 254431   14601.1AVC  DRIVE W/LIC SUSPEND/REVOKE 4 OTHER REASON
# 254432   23152(A)VC                DRUNK DRIVING ALCOHOL/DRUGS
#
#               Disposition Description      LAT       LON Booking Date  \
# 0         MISDEMEANOR COMPLAINT FILED  33.9908 -118.4765          NaT
# 1                  COUNSELED/RELEASED  34.2682 -118.4760          NaT
# 2         MISDEMEANOR COMPLAINT FILED  34.0845 -118.3091          NaT
# 3         MISDEMEANOR COMPLAINT FILED  34.0421 -118.2405          NaT
# 4         MISDEMEANOR COMPLAINT FILED  34.0539 -118.2756          NaT
# ...                               ...      ...       ...          ...
# 254428    MISDEMEANOR COMPLAINT FILED  34.0467 -118.2485   2023-02-04
# 254429  849(B)(1) PC/TECHNICAL ARREST  33.9356 -118.2652   2023-07-04
# 254430    MISDEMEANOR COMPLAINT FILED  34.0421 -118.2060   2023-07-06
# 254431    MISDEMEANOR COMPLAINT FILED  33.9420 -118.4095   2023-07-05
# 254432    MISDEMEANOR COMPLAINT FILED  34.0380 -118.3201   2023-07-03
#
#        Booking Time       Booking Location
# 0               NaN                    NaN
# 1               NaN                    NaN
# 2               NaN                    NaN
# 3               NaN                    NaN
# 4               NaN                    NaN
# ...             ...                    ...
# 254428     06:38 PM  METRO - JAIL DIVISION
# 254429     01:20 PM                77TH ST
# 254430     10:47 PM  METRO - JAIL DIVISION
# 254431     11:08 AM                PACIFIC
# 254432     03:30 AM  METRO - JAIL DIVISION
#
# [254433 rows x 18 columns]

# %%
#Dates type have been changed from object to date type. 
df.dtypes
# Out:
# Report ID                            int64
# Report Type                         object
# Arrest Date                 datetime64[ns]
# Time                                object
# Area Name                           object
# Age                                  int64
# Sex Code                            object
# Descent Code                        object
# Charge Group Description            object
# Arrest Type Code                    object
# Charge                              object
# Charge Description                  object
# Disposition Description             object
# LAT                                float64
# LON                                float64
# Booking Date                datetime64[ns]
# Booking Time                        object
# Booking Location                    object
# dtype: object

# %%
#Check for NaaN/Missing values in the dataset.
df.isna().sum()
# Out:
# Report ID                       0
# Report Type                     0
# Arrest Date                     0
# Time                         1630
# Area Name                       0
# Age                             0
# Sex Code                        0
# Descent Code                    0
# Charge Group Description    21241
# Arrest Type Code                1
# Charge                          0
# Charge Description          21200
# Disposition Description     19470
# LAT                             0
# LON                             0
# Booking Date                53756
# Booking Time                56268
# Booking Location            53789
# dtype: int64

# %%
#Select columns with NaN value
columns_of_interest = ['Charge Group Description', 'Time', 'Arrest Type Code', 'Charge Description', 'Disposition Description', 'Booking Date', 'Booking Time', 'Booking Location']

# Replace NaN values with 'N/A' only in specified columns
df[columns_of_interest] = df[columns_of_interest].fillna('N/A')

# Check for NaN values in the cleaned DataFrame
print(df.isna().sum())
# Out:
# Report ID                   0
# Report Type                 0
# Arrest Date                 0
# Time                        0
# Area Name                   0
# Age                         0
# Sex Code                    0
# Descent Code                0
# Charge Group Description    0
# Arrest Type Code            0
# Charge                      0
# Charge Description          0
# Disposition Description     0
# LAT                         0
# LON                         0
# Booking Date                0
# Booking Time                0
# Booking Location            0
# dtype: int64

# %%
df.shape
# Out:
# (254433, 18)

# %%
#Show N/A output 
df
# Out:
#         Report ID Report Type Arrest Date      Time   Area Name  Age Sex Code  \
# 0       231413977         RFC  2023-07-13  11:30 PM     Pacific   29        M
# 1       231715213         RFC  2023-09-01  11:00 PM  Devonshire   17        F
# 2       230612568         RFC  2023-07-14  09:50 PM   Hollywood   30        M
# 3       230119897         RFC  2023-09-13  01:32 PM     Central   50        M
# 4       230214008         RFC  2023-07-04  02:45 PM     Rampart   38        M
# ...           ...         ...         ...       ...         ...  ...      ...
# 254428    6547005     BOOKING  2023-02-04  01:00 PM     Central   38        F
# 254429    6635363     BOOKING  2023-07-04  11:30 AM   Southeast   33        M
# 254430    6636889     BOOKING  2023-07-06  08:50 PM  Hollenbeck   58        M
# 254431    6635947     BOOKING  2023-07-05  08:35 AM     Pacific   66        M
# 254432    6634656     BOOKING  2023-07-03  12:00 PM    Wilshire   36        M
#
#        Descent Code        Charge Group Description Arrest Type Code  \
# 0                 H                             N/A                I
# 1                 H                             N/A                M
# 2                 O             Prostitution/Allied                M
# 3                 A                             N/A                M
# 4                 H                             N/A                I
# ...             ...                             ...              ...
# 254428            W  Miscellaneous Other Violations                F
# 254429            H                   Vehicle Theft                F
# 254430            H                      Drunkeness                M
# 254431            O       Moving Traffic Violations                M
# 254432            H         Driving Under Influence                M
#
#              Charge                         Charge Description  \
# 0          25620(A)                                        N/A
# 1       45.03(A)LAM                                        N/A
# 2          647(B)PC                               PROSTITUTION
# 3       41.18A1LAMC                                        N/A
# 4       41.27(C)LAM                                        N/A
# ...             ...                                        ...
# 254428  594(B)(1)PC       VANDALISM W/LOSS VALUED EQ OR > $400
# 254429  487(D)(1)PC                 GRAND THEFT AUTO/HORSE/ETC
# 254430     647(F)PC            DISORD CONDUCT:UI/DRUG, ALCOHOL
# 254431   14601.1AVC  DRIVE W/LIC SUSPEND/REVOKE 4 OTHER REASON
# 254432   23152(A)VC                DRUNK DRIVING ALCOHOL/DRUGS
#
#               Disposition Description      LAT       LON         Booking Date  \
# 0         MISDEMEANOR COMPLAINT FILED  33.9908 -118.4765                  N/A
# 1                  COUNSELED/RELEASED  34.2682 -118.4760                  N/A
# 2         MISDEMEANOR COMPLAINT FILED  34.0845 -118.3091                  N/A
# 3         MISDEMEANOR COMPLAINT FILED  34.0421 -118.2405                  N/A
# 4         MISDEMEANOR COMPLAINT FILED  34.0539 -118.2756                  N/A
# ...                               ...      ...       ...                  ...
# 254428    MISDEMEANOR COMPLAINT FILED  34.0467 -118.2485  2023-02-04 00:00:00
# 254429  849(B)(1) PC/TECHNICAL ARREST  33.9356 -118.2652  2023-07-04 00:00:00
# 254430    MISDEMEANOR COMPLAINT FILED  34.0421 -118.2060  2023-07-06 00:00:00
# 254431    MISDEMEANOR COMPLAINT FILED  33.9420 -118.4095  2023-07-05 00:00:00
# 254432    MISDEMEANOR COMPLAINT FILED  34.0380 -118.3201  2023-07-03 00:00:00
#
#        Booking Time       Booking Location
# 0               N/A                    N/A
# 1               N/A                    N/A
# 2               N/A                    N/A
# 3               N/A                    N/A
# 4               N/A                    N/A
# ...             ...                    ...
# 254428     06:38 PM  METRO - JAIL DIVISION
# 254429     01:20 PM                77TH ST
# 254430     10:47 PM  METRO - JAIL DIVISION
# 254431     11:08 AM                PACIFIC
# 254432     03:30 AM  METRO - JAIL DIVISION
#
# [254433 rows x 18 columns]

# %% [markdown]
# # Step 3 Summary Statistic

# %%
 # Show statisic of the number value of the dataset
df.describe()
# Out:
#           Report ID                    Arrest Date            Age  \
# count  2.544330e+05                         254433  254433.000000
# mean   5.057848e+07  2021-12-02 12:15:00.392637696      35.063765
# min    1.062984e+06            2020-01-01 00:00:00       0.000000
# 25%    6.143556e+06            2020-12-09 00:00:00      26.000000
# 50%    6.390053e+06            2021-11-16 00:00:00      33.000000
# 75%    6.676268e+06            2022-12-01 00:00:00      42.000000
# max    2.321169e+08            2023-11-25 00:00:00      96.000000
# std    8.575277e+07                            NaN      12.334002
#
#                  LAT            LON
# count  254433.000000  254433.000000
# mean       33.456864    -116.202648
# min         0.000000    -118.667600
# 25%        34.003700    -118.437300
# 50%        34.056300    -118.311300
# 75%        34.174000    -118.273500
# max        34.334300       0.000000
# std         4.553691      15.811714

# %%
#Summary Information on the non-numeric columns
df.describe(include='object')
# Out:
#        Report Type      Time Area Name Sex Code Descent Code  \
# count       254433    254433    254433   254433       254433
# unique           2      1301        21        2           19
# top        BOOKING  01:00 PM   Rampart        M            H
# freq        200677      3772     18632   202282       131366
#
#               Charge Group Description Arrest Type Code      Charge  \
# count                           254433           254433      254433
# unique                              28                7        3997
# top     Miscellaneous Other Violations                F  273.5(A)PC
# freq                             34237           120509       15545
#
#        Charge Description      Disposition Description Booking Date  \
# count              254433                       254433       254433
# unique               1331                           23         1437
# top                   N/A  MISDEMEANOR COMPLAINT FILED          N/A
# freq                21200                       131450        53756
#
#        Booking Time       Booking Location
# count        254433                 254433
# unique         1300                     25
# top             N/A  METRO - JAIL DIVISION
# freq          56268                  61278

# %%
# What are Top 10 highest Charges Description?  
df['Charge Group Description'].value_counts()[:10]
# Out:
# Charge Group Description
# Miscellaneous Other Violations    34237
# Aggravated Assault                32647
# Other Assaults                    23172
# Driving Under Influence           23038
# Narcotic Drug Laws                21437
# N/A                               21241
# Weapon (carry/poss)               16877
# Vehicle Theft                     12938
# Larceny                            9133
# Prostitution/Allied                8853
# Name: count, dtype: int64

# %% [markdown]
# # Step 3: Data Visualization And Questions Answered
#
# What are the Top 10 Age Group in dataste?
#
# Answer- 29 years old

# %%
charge_description = df['Charge Group Description'].value_counts()[:10]

# Display the relative frequencies
display(charge_description / df.shape[0])

# Bar Chart
(charge_description / df.shape[0]).plot(kind='bar')
plt.title('Top 10 Charges (as % of all charges)')
plt.show()
# Out:
# Charge Group Description
# Miscellaneous Other Violations    0.134562
# Aggravated Assault                0.128313
# Other Assaults                    0.091073
# Driving Under Influence           0.090546
# Narcotic Drug Laws                0.084254
# N/A                               0.083484
# Weapon (carry/poss)               0.066332
# Vehicle Theft                     0.050850
# Larceny                           0.035896
# Prostitution/Allied               0.034795
# Name: count, dtype: float64

# %%
# Bar Chart
ax = df['Age'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Top Age group in Arrest Data')
ax.set_xlabel('Age Range')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Pie Chart

top_age_groups = df['Age'].value_counts().head(20)

top_age_groups.plot(kind='pie', autopct='%1.1f%%')
plt.axis('equal') #Equal aspect ratio ensures that the pie chart is circular
plt.title('Top Age Groups in Arrest Data')
plt.show()

# %%
#Seaborn library create visually appealing and informative statistical graphics

sns.barplot(data=df, x='Age', 
            y='Charge Group Description', 
            hue='Sex Code', 
            palette={'M': 'blue', 'F': 'red'})

plt.title('Stacked Bar Chart of Charges by Age Group')
plt.xlabel('Age')
plt.ylabel('Charge Group Description')
plt.legend(title='Sex Code')

plt.show()

# %% [markdown]
# # Step 4: Export Cleaned Data

# %%
#Data cleaned now I can export the new cleaned data into a CSV file.
df.to_csv('new_cleaned_data.csv', index=False)
